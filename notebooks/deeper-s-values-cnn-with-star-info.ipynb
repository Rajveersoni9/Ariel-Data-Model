# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ariel_pred.dataset import DataLoaderAndCalibrator
from ariel_pred.preprocessing import SGSmoothing
from ariel_pred.plots import plot_white_curve
from ariel_pred.transit import FunctionFittingBasedPhaseDetector
from ariel_pred.models import TransitMultiplicationFactorFinder, SValuesCNN, SValuesCNNTrainer
from ariel_pred.features import WavelengthsGroupsMultiplierFinder
from ariel_pred.metrics import score, gll
from ariel_pred.sigma import OGSignalVarBasedSigmaCalculator
from ariel_pred.modeling.deep_s_values_cnn_with_star_info import DeepSValuesCNNWithStarInfoModel, DeepSValuesCNNWithStarInfoTrainer
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import random
from scipy.optimize import minimize
from tqdm.auto import tqdm
import pandas as pd
import torch
from torch import nn
import scipy

# %%
data_loader = DataLoaderAndCalibrator(
    data_path=Path("../data/raw"),
    output_path=Path("../data/calibrated/full"),
    force_recalibration=False,
    cut_airs_channels=True,
    binning=4,
    n_jobs=4
)
train_data, train_labels = data_loader.load_all_train_data()
train_data.shape, train_labels.shape
# Out:
# Loading calibrated train data...
# ((1100, 1406, 283), (1100, 283))

# %%
features_extractor = WavelengthsGroupsMultiplierFinder()

features = features_extractor.extract_features(
    train_data,
    average_cross_groups=False,
    wavelengths_groups=[1, 2, 4, 8, 16, 32, 64],
    weights=[1, 1, 1, 1, 1, 1, 1]
)

features.shape
# Out:
#   0%|          | 0/1100 [00:00<?, ?it/s]
# (1100, 283, 7)

# %%
model_data = features.transpose(0, 2,1)
model_data.shape
# Out:
# (1100, 7, 283)

# %%
star_info_df = pd.read_csv("../data/raw/train_star_info.csv")
star_info_df.head()
# Out:
#    planet_id        Rs        Ms           Ts        Mp    e         P  \
# 0      34983  1.155435  1.062961  5577.006645  0.694946  0.0  3.305589
# 1    1873185  1.813230  1.370451  6216.229756  0.610845  0.0  6.352660
# 2    3849793  0.653807  0.667352  4968.477186  1.529200  0.0  5.522798
# 3    8456603  1.250623  1.162019  6023.702622  2.262107  0.0  7.541019
# 4   23615382  1.431492  1.306489  6128.061013  0.861299  0.0  4.368080
#
#          sma          i
# 0   8.550786  89.150759
# 1   9.553384  88.701514
# 2  15.285661  89.134177
# 3  14.144310  87.178007
# 4   8.347654  90.000000

# %%
star_info = star_info_df[["Rs", "i"]].values
star_info.shape
# Out:
# (1100, 2)

# %%
trainer = DeepSValuesCNNWithStarInfoTrainer(
    Path("../models/s_values_cnn_with_star_info_deep"),
    n_splits=5,
    num_channels=model_data.shape[1],
    wavelengths=model_data.shape[2],
    num_star_features=star_info.shape[1],
)
val_losses, train_losses, val_preds_list = trainer.train(model_data*1e3, star_info, train_labels*1e3, epochs=300)
# Out:
# Fold 1/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/s_values_cnn_with_star_info_deep/model_fold_1.pt
# Fold 2/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/s_values_cnn_with_star_info_deep/model_fold_2.pt
# Fold 3/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/s_values_cnn_with_star_info_deep/model_fold_3.pt
# Fold 4/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/s_values_cnn_with_star_info_deep/model_fold_4.pt
# Fold 5/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/s_values_cnn_with_star_info_deep/model_fold_5.pt

# %%
val_preds_list.shape, train_labels.shape
# Out:
# ((1100, 283), (1100, 283))

# %%
predections = val_preds_list / 1e3
np.sqrt(np.mean((predections - train_labels)**2))
# Out:
# np.float64(0.0006115678822410079)

# %%
import os
os.makedirs("../models/s_values_cnn_with_star_info_res_deep", exist_ok=True)
np.save("../models/s_values_cnn_with_star_info_res_deep/s_values_cnn_with_star_info_val_preds.npy", predections)

# %%
np.sqrt(np.mean((predections[:, 0] - train_labels[:, 0])**2))
# Out:
# np.float64(0.000873508190561184)

# %%
spectrum = predections
sigma_calculator = OGSignalVarBasedSigmaCalculator(
    mean_fgs_sigma = 9.0e-4,
    mean_airs_sigma = 5.5e-4,
    fgs_min_sigma = 1e-6,
    airs_min_sigma = 1e-6,
)
sigma = sigma_calculator.get_sigma(train_data)
gll(np.concatenate([spectrum, sigma], axis=1), train_labels)
# Out:
#   0%|          | 0/1100 [00:00<?, ?it/s]
# Calculating FGS sigma:   0%|          | 0/1100 [00:00<?, ?it/s]
# Calculating AIRS sigma:   0%|          | 0/1100 [00:00<?, ?it/s]
# 0.4015522678676334

# %%
airs_errors = np.abs(predections[:, 1:] - train_labels[:, 1:]).flatten()
airs_flat_sigma = sigma[:, 1:].flatten()
plt.plot(np.sort(airs_errors))
plt.plot(airs_flat_sigma[np.argsort(airs_errors)], alpha=0.5)
plt.show()

# %%
sigma[:, 1:].max(), np.percentile(sigma[:, 1:], 95), np.median(sigma[:, 1:]), np.percentile(sigma[:, 1:], 5), sigma[:, 1:].min()
# Out:
# (np.float64(0.02429949718853478),
#  np.float64(0.001031898020904438),
#  np.float64(0.00047789578447402913),
#  np.float64(0.000299965589421705),
#  np.float64(0.0002093483337605096))

# %%
np.percentile(np.abs(predections[:, 1:] - train_labels[:, 1:]), 95), np.percentile(np.abs(predections[:, 1:] - train_labels[:, 1:]), 5)
# Out:
# (np.float64(0.0009581749790276696), np.float64(1.5311039896562412e-05))

# %%
fgs_errors = np.abs(predections[:, 0] - train_labels[:, 0]).flatten()
fgs_flat_sigma = sigma[:, 0].flatten()
plt.plot(np.sort(fgs_errors))
plt.plot(fgs_flat_sigma[np.argsort(fgs_errors)], alpha=0.5)
plt.show()
