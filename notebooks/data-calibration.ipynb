# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ariel_pred.config import Config
from ariel_pred.dataset import SignalProcessor

# %%
cfg = Config()
signal_processor = SignalProcessor(cfg)

# %%
train_data= signal_processor.process_all_data('train')
test_data= signal_processor.process_all_data('test')
# Out:
# QUEUEING TASKS | : 100%|██████████| 9/9 [00:00<00:00, 10585.74it/s]
# PROCESSING TASKS | : 100%|██████████| 9/9 [00:40<00:00,  4.49s/it]
# COLLECTING RESULTS | : 100%|██████████| 9/9 [00:00<00:00, 128835.28it/s]
# QUEUEING TASKS | : 100%|██████████| 9/9 [00:00<00:00, 7259.37it/s]
# PROCESSING TASKS | : 100%|██████████| 9/9 [00:17<00:00,  1.90s/it]
# COLLECTING RESULTS | : 100%|██████████| 9/9 [00:00<00:00, 263977.17it/s]

# %%
train_data.shape, test_data.shape
# Out:
# ((9, 187, 283), (1, 187, 283))
