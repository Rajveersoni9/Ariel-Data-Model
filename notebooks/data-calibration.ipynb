# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ariel_pred.config import Config
from ariel_pred.dataset import SignalProcessor

# %%
cfg = Config()
signal_processor = SignalProcessor(cfg)

# %%
s = signal_processor.process_all_data()
# Out:
# QUEUEING TASKS | : 100%|██████████| 9/9 [00:00<00:00, 9627.32it/s]
# PROCESSING TASKS | : 100%|██████████| 9/9 [00:38<00:00,  4.26s/it]
# COLLECTING RESULTS | : 100%|██████████| 9/9 [00:00<00:00, 50805.84it/s]
# QUEUEING TASKS | : 100%|██████████| 9/9 [00:00<00:00, 8538.51it/s]
# PROCESSING TASKS | : 100%|██████████| 9/9 [00:16<00:00,  1.85s/it]
# COLLECTING RESULTS | : 100%|██████████| 9/9 [00:00<00:00, 235929.60it/s]

# %%
s.shape
# Out:
# (9, 187, 283)
