# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ariel_pred.dataset import DataLoaderAndCalibrator
from ariel_pred.preprocessing import SGSmoothing
from ariel_pred.plots import plot_white_curve
from ariel_pred.transit import FunctionFittingBasedPhaseDetector
from ariel_pred.models import TransitMultiplicationFactorFinder, SValuesCNN, SValuesCNNTrainer
from ariel_pred.features import WavelengthsGroupsMultiplierFinder
from ariel_pred.metrics import score, gll
from ariel_pred.sigma import OGSignalVarBasedSigmaCalculator
from ariel_pred.modeling.s_values_cnn_with_star_info import SValuesCNNWithStarInfoModel, SValuesCNNWithStarInfoTrainer
from ariel_pred.modeling.nn_with_sigma_pred import ResNetAndCNNWithSigmaModelTrainer
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import random
from scipy.optimize import minimize
from tqdm.auto import tqdm
import pandas as pd
import torch
from torch import nn
import scipy

# %%
data_loader = DataLoaderAndCalibrator(
    data_path=Path("../data/raw"),
    output_path=Path("../data/calibrated/full"),
    force_recalibration=False,
    cut_airs_channels=True,
    binning=4,
    n_jobs=4
)
train_data, train_labels = data_loader.load_all_train_data()
train_data.shape, train_labels.shape
# Out:
# Loading calibrated train data...
# ((1100, 1406, 283), (1100, 283))

# %%
features_extractor = WavelengthsGroupsMultiplierFinder()

features = features_extractor.extract_features(
    train_data,
    average_cross_groups=False,
    wavelengths_groups=[1, 2, 4, 8, 16, 32, 64],
    weights=[1, 1, 1, 1, 1, 1, 1]
)

features.shape
# Out:
#   0%|          | 0/1100 [00:00<?, ?it/s]
# (1100, 283, 7)

# %%
model_data = features.transpose(0, 2,1)
model_data.shape
# Out:
# (1100, 7, 283)

# %%
star_info_df = pd.read_csv("../data/raw/train_star_info.csv")
star_info_df.head()
# Out:
#    planet_id        Rs        Ms           Ts        Mp    e         P  \
# 0      34983  1.155435  1.062961  5577.006645  0.694946  0.0  3.305589
# 1    1873185  1.813230  1.370451  6216.229756  0.610845  0.0  6.352660
# 2    3849793  0.653807  0.667352  4968.477186  1.529200  0.0  5.522798
# 3    8456603  1.250623  1.162019  6023.702622  2.262107  0.0  7.541019
# 4   23615382  1.431492  1.306489  6128.061013  0.861299  0.0  4.368080
#
#          sma          i
# 0   8.550786  89.150759
# 1   9.553384  88.701514
# 2  15.285661  89.134177
# 3  14.144310  87.178007
# 4   8.347654  90.000000

# %%
star_info = star_info_df[["Rs", "i"]].values
star_info.shape
# Out:
# (1100, 2)

# %%
trainer = ResNetAndCNNWithSigmaModelTrainer(
    Path("../models/resnet_cnn_with_star_info_sigma_pred"),
    n_splits=5,
    num_channels=model_data.shape[1],
    wavelengths=model_data.shape[2],
    num_star_features=star_info.shape[1]
)
val_losses, train_losses, spectrum_preds, sigma_preds = trainer.train(model_data*1e3, star_info, train_labels*1e3, epochs=300)
# Out:
# Fold 1/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/resnet_cnn_with_star_info_sigma_pred/model_fold_1.pt
# Fold 2/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/resnet_cnn_with_star_info_sigma_pred/model_fold_2.pt
# Fold 3/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/resnet_cnn_with_star_info_sigma_pred/model_fold_3.pt
# Fold 4/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/resnet_cnn_with_star_info_sigma_pred/model_fold_4.pt
# Fold 5/5
# Training:   0%|          | 0/300 [00:00<?, ?it/s]
# Loading weights from ../models/resnet_cnn_with_star_info_sigma_pred/model_fold_5.pt

# %%
predictions = spectrum_preds / 1e3
sigma = sigma_preds / 1e3
predictions.shape, sigma.shape
# Out:
# ((1100, 283), (1100,))

# %%
np.sqrt(np.mean((predictions - train_labels)**2))
# Out:
# np.float64(0.0005852979906140655)

# %%
np.sqrt(np.mean((predictions[:, 0] - train_labels[:, 0])**2))
# Out:
# np.float64(0.0008704935288056279)

# %%
np.sqrt(np.mean((predictions[:,1:] - train_labels[:, 1:])**2))
# Out:
# np.float64(0.0005840389111274358)

# %%
gll(np.concatenate([predictions, np.repeat(sigma[:, np.newaxis], 283, axis=1)], axis=1), train_labels)
# Out:
# 0.400918391499471

# %%
airs_errors = np.abs(predictions[:, 1:] - train_labels[:, 1:]).flatten()
airs_flat_sigma = np.repeat(sigma[:, np.newaxis], 282, axis=1).flatten()
plt.plot(np.sort(airs_errors))
plt.plot(airs_flat_sigma[np.argsort(airs_errors)], alpha=0.5)
plt.show()

# %%
sigma
# Out:
# array([0.00082503, 0.00062046, 0.00131305, ..., 0.00039751, 0.00045534,
#        0.00073411], shape=(1100,), dtype=float32)

# %%
old_sigma_calculator = OGSignalVarBasedSigmaCalculator(
    mean_fgs_sigma = 8.5e-4,
    mean_airs_sigma = 5.5e-4,
    fgs_min_sigma = 1e-6,
    airs_min_sigma = 1e-6,
)
old_sigma = old_sigma_calculator.get_sigma(train_data)
gll(np.concatenate([predictions, old_sigma], axis=1), train_labels)
# Out:
#   0%|          | 0/1100 [00:00<?, ?it/s]
# Calculating FGS sigma:   0%|          | 0/1100 [00:00<?, ?it/s]
# Calculating AIRS sigma:   0%|          | 0/1100 [00:00<?, ?it/s]
# 0.40548448790065666

# %%
merged_sigma = (old_sigma + np.repeat(sigma[:, np.newaxis], 283, axis=1)) / 2

gll(np.concatenate([predictions, merged_sigma], axis=1), train_labels)
# Out:
# 0.41005047834660324
